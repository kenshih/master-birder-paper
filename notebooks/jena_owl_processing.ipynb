# %% [markdown]
# # Jena-based OWL Processing for Large Taxonomic Ontologies
#
# This notebook demonstrates how to process large OWL files using Apache Jena and related tools.
#
# ## Files to Process:
# - `ncbitaxon.owl` (~1.7GB) - NCBI Taxonomy
# - `taxmeon.owl` (~61KB) - TaxMeOn ontology
#
# ## Processing Methods:
# 1. **RDFLib with streaming** - Memory efficient for large files
# 2. **Database storage** - For efficient querying
# 3. **Jena Java API** - Full OWL reasoning capabilities
# 4. **SPARQL queries** - For complex queries

# %%
# Import required libraries
import sys
import os
from pathlib import Path
import pandas as pd
import sqlite3
import time
import logging

# Add scripts directory to path
sys.path.append('../scripts')

# Import our custom processor
from jena_owl_processor import JenaOWLProcessor

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

print("Libraries imported successfully!")
